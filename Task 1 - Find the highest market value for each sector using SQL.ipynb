# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Rohan\Github\SQL\Coding Easy Tasks\Highest Market Value per Sector - Task 1.csv')

# %%
df.head()
# Out:
#                       company      sector             industry      continent  \
# 0                        ICBC  Financials          Major Banks           Asia
# 1     China Construction Bank  Financials       Regional Banks           Asia
# 2  Agricultural Bank of China  Financials       Regional Banks           Asia
# 3              JPMorgan Chase  Financials          Major Banks  North America
# 4          Berkshire Hathaway  Financials  Investment Services  North America
#
#          country  marketvalue  sales  profits  assets  rank  \
# 0          China        215.6  148.7     42.7  3124.9     1
# 1          China        174.4  121.3     34.2  2449.5     2
# 2          China        141.1  136.4     27.0  2405.4     3
# 3  United States        229.7  105.7     17.3  2435.3     4
# 4  United States        309.1  178.8     19.5   493.4     5
#
#                                        forbeswebpage
# 0              http://www.forbes.com/companies/icbc/
# 1  http://www.forbes.com/companies/china-construc...
# 2  http://www.forbes.com/companies/agricultural-b...
# 3    http://www.forbes.com/companies/jpmorgan-chase/
# 4  http://www.forbes.com/companies/berkshire-hath...

# %%
df.tail()
# Out:
#                    company                  sector                 industry  \
# 95            CVS Caremark        Consumer Staples              Drug Retail
# 96               ING Group              Financials  Life & Health Insurance
# 97  Saudi Basic Industries               Materials    Diversified Chemicals
# 98              Merck & Co             Health Care          Pharmaceuticals
# 99             Walt Disney  Consumer Discretionary     Broadcasting & Cable
#
#         continent        country  marketvalue  sales  profits  assets  rank  \
# 95  North America  United States         87.8  126.8      4.6    71.5    96
# 96         Europe    Netherlands         56.1   34.5      4.4  1488.7    97
# 97           Asia   Saudi Arabia         94.4   50.4      6.7    90.4    98
# 98  North America  United States        165.8   44.1      4.4   105.6    99
# 99  North America  United States        142.9   46.0      6.6    83.2   100
#
#                                         forbeswebpage
# 95      http://www.forbes.com/companies/cvs-caremark/
# 96         http://www.forbes.com/companies/ing-group/
# 97  http://www.forbes.com/companies/saudi-basic-in...
# 98          http://www.forbes.com/companies/merck-co/
# 99       http://www.forbes.com/companies/walt-disney/

# %%
# Import sqlite3 package
import sqlite3

# %%
# Obtain all the columns of this dataset
df.columns
# Out:
# Index(['company', 'sector', 'industry', 'continent', 'country', 'marketvalue',
#        'sales', 'profits', 'assets', 'rank', 'forbeswebpage'],
#       dtype='object')

# %%
# Obtain the dimensions of this dataset
df.shape
# Out:
# (100, 11)

# %% [markdown]
# This dataset has about 100 rows and 11 columns

# %%
# import sqlalchemy and create a sqlite engine
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)

# export the dataframe as a table to the sqlite engine
df.to_sql("df", con =engine)
# Out:
# 100

# %%
## Test the code by select the complete table
# Obtain the first 5 rows

sql='''

Select * from df
limit 5


''';

    
df_sql = pd.read_sql_query(sql,con=engine)
df_sql.head()
# Out:
#    index                     company      sector             industry  \
# 0      0                        ICBC  Financials          Major Banks
# 1      1     China Construction Bank  Financials       Regional Banks
# 2      2  Agricultural Bank of China  Financials       Regional Banks
# 3      3              JPMorgan Chase  Financials          Major Banks
# 4      4          Berkshire Hathaway  Financials  Investment Services
#
#        continent        country  marketvalue  sales  profits  assets  rank  \
# 0           Asia          China        215.6  148.7     42.7  3124.9     1
# 1           Asia          China        174.4  121.3     34.2  2449.5     2
# 2           Asia          China        141.1  136.4     27.0  2405.4     3
# 3  North America  United States        229.7  105.7     17.3  2435.3     4
# 4  North America  United States        309.1  178.8     19.5   493.4     5
#
#                                        forbeswebpage
# 0              http://www.forbes.com/companies/icbc/
# 1  http://www.forbes.com/companies/china-construc...
# 2  http://www.forbes.com/companies/agricultural-b...
# 3    http://www.forbes.com/companies/jpmorgan-chase/
# 4  http://www.forbes.com/companies/berkshire-hath...

# %%
# Obtain the total number of records from this table
sql='''

SELECT COUNT(*) AS [Total Number of Records]
FROM df;


''';

    
df_sql = pd.read_sql_query(sql,con=engine)
df_sql
# Out:
#    Total Number of Records
# 0                      100

# %%
# Find the highest market value for each sector
sql='''

SELECT sector, MAX(marketvalue) AS [Highest Market Value]
FROM df
GROUP BY sector;


''';

    
df_sql = pd.read_sql_query(sql,con=engine)
df_sql
# Out:
#                        sector  Highest Market Value
# 0      Consumer Discretionary                 247.9
# 1            Consumer Staples                 239.6
# 2                      Energy                 422.3
# 3                  Financials                 309.1
# 4                 Health Care                 277.0
# 5                 Industrials                 259.6
# 6      Information Technology                 483.1
# 7                   Materials                 182.3
# 8  Telecommunication Services                 197.7
# 9                   Utilities                  75.8

# %%
# Sort the above table in descending order
sql='''

SELECT sector, MAX(marketvalue) AS [Highest Market Value]
FROM df
GROUP BY sector
ORDER BY [Highest Market Value] DESC;


''';

    
df_sql = pd.read_sql_query(sql,con=engine)
df_sql
# Out:
#                        sector  Highest Market Value
# 0      Information Technology                 483.1
# 1                      Energy                 422.3
# 2                  Financials                 309.1
# 3                 Health Care                 277.0
# 4                 Industrials                 259.6
# 5      Consumer Discretionary                 247.9
# 6            Consumer Staples                 239.6
# 7  Telecommunication Services                 197.7
# 8                   Materials                 182.3
# 9                   Utilities                  75.8
